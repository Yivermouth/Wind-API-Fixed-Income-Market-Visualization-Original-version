# %% [markdown]
# ## 【汇总】

# %%
#来自ChatGPT
from IPython.display import display

# %% [markdown]
# ## 请注意，.ipynb 文件与 .py 文件有所不同

# %%
output = %run a_done_OMO.ipynb

# %%
output = %run b_done_lilvzhai.ipynb
# Out:
# 2025/01/18 <class 'str'> 2025/01/25 <class 'str'>

# %%
output = %run c_done_NCD.ipynb
# Out:
# 2025/01/18 <class 'str'> 2025/01/25 <class 'str'>

# %%
output = %run d_done_credit_bond.ipynb
#【注意】：因为前面每个子脚本最终结果都是图表，但这个最终结果是一个dataframe的表格不是图表，所以要单独把这个对象打出来才能正常显示
credit_bond_data_IA.T
# Out:
# 2025/01/18 <class 'str'> 2025/01/25 <class 'str'>
# Wind债券一级分类 中期票据                公司债                  短期融资券                  Total
# 主体评级            AA     AA+     AAA     AA     AA+      AAA       AA      AA+     AAA
# 发行人省份
# 上海                  -        -    25.0    8.0        -       -        -      3.0   117.0     153.0
# 云南省              5.0        -    10.0    2.0        -    14.0        -        -       -      31.0
# 北京                5.0        -   137.0      -     12.0     2.0        -        -   109.4     265.4
# 吉林省                -        -       -      -        -   11.13        -        -       -     11.13
# 四川省                -     9.27    30.0  11.37      7.0    20.0        -      0.0       -     77.64
# 天津                  -      5.0    11.0      -        -       -        -    18.25    10.0     44.25
# 安徽省              5.0        -       -      -      6.0       -        -        -    10.0      21.0
# ...
